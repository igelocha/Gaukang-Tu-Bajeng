# %% [markdown]
# <a href="https://colab.research.google.com/github/igelocha/Gaukang-Tu-Bajeng/blob/main/Landing_Page_GTB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html lang="id">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>Gaukang Tu Bajeng</title>
<link href="https://fonts.googleapis.com/css2?family=Cinzel+Decorative:wght@700;900&family=Playfair+Display:wght@400;600;700&family=Nunito:wght@400;600;700&display=swap" rel="stylesheet">
<style>
  :root {
    --green-deep: #1a4a1e;
    --green-mid: #2d7a35;
    --green-bright: #4caf50;
    --green-light: #a8d5ab;
    --gold: #c9a227;
    --gold-light: #f0d060;
    --cream: #fdf6e3;
    --brown: #5c3317;
    --white: #ffffff;
  }

  * { margin: 0; padding: 0; box-sizing: border-box; }

  body {
    font-family: 'Nunito', sans-serif;
    background: var(--green-deep);
    color: var(--cream);
    overflow-x: hidden;
  }

  /* === HERO SECTION === */
  .hero {
    min-height: 100vh;
    background:
      radial-gradient(ellipse at 20% 50%, rgba(44,122,53,0.5) 0%, transparent 60%),
      radial-gradient(ellipse at 80% 20%, rgba(201,162,39,0.2) 0%, transparent 50%),
      linear-gradient(160deg, #0d2b10 0%, #1a4a1e 40%, #0f3512 100%);
    display: flex;
    flex-direction: column;
    align-items: center;
    justify-content: center;
    text-align: center;
    padding: 40px 20px;
    position: relative;
    overflow: hidden;
  }

  .hero::before {
    content: '';
    position: absolute;
    inset: 0;
    background-image:
      radial-gradient(circle at 15% 85%, rgba(201,162,39,0.15) 0%, transparent 30%),
      radial-gradient(circle at 85% 15%, rgba(76,175,80,0.1) 0%, transparent 35%);
    pointer-events: none;
  }

  /* Decorative ornament top */
  .ornament-top {
    position: absolute;
    top: 0;
    left: 0;
    right: 0;
    height: 8px;
    background: linear-gradient(90deg, var(--green-deep), var(--gold), var(--green-bright), var(--gold), var(--green-deep));
  }

  .hero-badge {
    display: inline-block;
    background: rgba(201,162,39,0.15);
    border: 1px solid rgba(201,162,39,0.4);
    color: var(--gold-light);
    font-size: 12px;
    font-weight: 700;
    letter-spacing: 3px;
    text-transform: uppercase;
    padding: 6px 20px;
    border-radius: 30px;
    margin-bottom: 24px;
    animation: fadeDown 0.8s ease forwards;
  }

  .hero-logo {
    width: 90px;
    height: 90px;
    background: linear-gradient(135deg, var(--green-mid), var(--green-bright));
    border-radius: 22px;
    border: 3px solid var(--gold);
    display: flex;
    align-items: center;
    justify-content: center;
    font-size: 36px;
    margin-bottom: 24px;
    box-shadow: 0 8px 40px rgba(201,162,39,0.3), 0 0 0 8px rgba(201,162,39,0.08);
    animation: fadeDown 0.9s ease forwards;
  }

  .hero-title {
    font-family: 'Cinzel Decorative', serif;
    font-size: clamp(2.4rem, 6vw, 4.5rem);
    font-weight: 900;
    color: var(--gold-light);
    text-shadow: 0 2px 20px rgba(201,162,39,0.4), 0 0 60px rgba(201,162,39,0.15);
    line-height: 1.1;
    margin-bottom: 8px;
    animation: fadeDown 1s ease forwards;
  }

  .hero-subtitle {
    font-family: 'Playfair Display', serif;
    font-size: clamp(0.9rem, 2.5vw, 1.2rem);
    color: var(--green-light);
    letter-spacing: 1.5px;
    margin-bottom: 20px;
    font-style: italic;
    animation: fadeDown 1.1s ease forwards;
  }

  .hero-desc {
    max-width: 600px;
    font-size: clamp(0.9rem, 2vw, 1.05rem);
    color: rgba(253,246,227,0.8);
    line-height: 1.7;
    margin-bottom: 40px;
    animation: fadeDown 1.2s ease forwards;
  }

  .hero-divider {
    width: 120px;
    height: 2px;
    background: linear-gradient(90deg, transparent, var(--gold), transparent);
    margin: 0 auto 40px;
  }

  .btn-group {
    display: flex;
    gap: 14px;
    flex-wrap: wrap;
    justify-content: center;
    animation: fadeUp 1.3s ease forwards;
  }

  .btn-primary {
    padding: 14px 40px;
    background: linear-gradient(135deg, var(--gold), #a07a10);
    color: var(--green-deep);
    font-family: 'Nunito', sans-serif;
    font-weight: 800;
    font-size: 1rem;
    border: none;
    border-radius: 50px;
    cursor: pointer;
    text-decoration: none;
    box-shadow: 0 6px 25px rgba(201,162,39,0.4);
    transition: all 0.3s ease;
    letter-spacing: 0.5px;
  }

  .btn-primary:hover {
    transform: translateY(-3px);
    box-shadow: 0 10px 35px rgba(201,162,39,0.55);
    background: linear-gradient(135deg, var(--gold-light), var(--gold));
  }

  .btn-secondary {
    padding: 14px 36px;
    background: transparent;
    color: var(--cream);
    font-family: 'Nunito', sans-serif;
    font-weight: 700;
    font-size: 1rem;
    border: 2px solid rgba(253,246,227,0.4);
    border-radius: 50px;
    cursor: pointer;
    text-decoration: none;
    transition: all 0.3s ease;
    letter-spacing: 0.5px;
  }

  .btn-secondary:hover {
    border-color: var(--gold);
    color: var(--gold-light);
    transform: translateY(-3px);
  }

  .btn-ghost {
    padding: 10px 24px;
    background: transparent;
    color: var(--green-light);
    font-size: 0.9rem;
    border: none;
    cursor: pointer;
    text-decoration: underline;
    transition: color 0.2s;
  }

  .btn-ghost:hover { color: var(--gold-light); }

  /* SDGs Badges */
  .sdgs-row {
    display: flex;
    gap: 10px;
    justify-content: center;
    flex-wrap: wrap;
    margin-top: 36px;
    animation: fadeUp 1.5s ease forwards;
  }

  .sdg-badge {
    background: rgba(255,255,255,0.08);
    border: 1px solid rgba(201,162,39,0.3);
    border-radius: 8px;
    padding: 6px 12px;
    font-size: 11px;
    color: var(--gold-light);
    font-weight: 700;
    letter-spacing: 1px;
  }

  /* === ABOUT SECTION === */
  .about {
    padding: 100px 20px;
    background: linear-gradient(180deg, #0d2b10 0%, #142e18 100%);
    position: relative;
  }

  .container {
    max-width: 1100px;
    margin: 0 auto;
  }

  .section-header {
    text-align: center;
    margin-bottom: 60px;
  }

  .section-tag {
    display: inline-block;
    color: var(--gold);
    font-size: 12px;
    font-weight: 700;
    letter-spacing: 4px;
    text-transform: uppercase;
    margin-bottom: 12px;
  }

  .section-title {
    font-family: 'Cinzel Decorative', serif;
    font-size: clamp(1.6rem, 4vw, 2.8rem);
    color: var(--gold-light);
    line-height: 1.2;
    margin-bottom: 16px;
  }

  .section-desc {
    font-family: 'Playfair Display', serif;
    font-size: 1.05rem;
    color: rgba(253,246,227,0.7);
    max-width: 620px;
    margin: 0 auto;
    line-height: 1.8;
    font-style: italic;
  }

  .about-text-card {
    background: rgba(255,255,255,0.04);
    border: 1px solid rgba(201,162,39,0.2);
    border-radius: 16px;
    padding: 36px;
    font-size: 1rem;
    line-height: 1.8;
    color: rgba(253,246,227,0.85);
    border-left: 4px solid var(--gold);
    margin-bottom: 60px;
  }

  /* === FEATURES GRID === */
  .features {
    padding: 80px 20px;
    background: linear-gradient(180deg, #142e18 0%, #1a4a1e 100%);
  }

  .features-grid {
    display: grid;
    grid-template-columns: repeat(auto-fit, minmax(200px, 1fr));
    gap: 20px;
    margin-top: 50px;
  }

  .feature-card {
    background: rgba(255,255,255,0.05);
    border: 1px solid rgba(201,162,39,0.2);
    border-radius: 16px;
    padding: 30px 20px;
    text-align: center;
    transition: all 0.3s ease;
    position: relative;
    overflow: hidden;
  }

  .feature-card::before {
    content: '';
    position: absolute;
    top: 0; left: 0; right: 0;
    height: 3px;
    background: linear-gradient(90deg, var(--green-mid), var(--gold));
    opacity: 0;
    transition: opacity 0.3s;
  }

  .feature-card:hover {
    transform: translateY(-6px);
    border-color: rgba(201,162,39,0.5);
    background: rgba(255,255,255,0.08);
    box-shadow: 0 12px 40px rgba(0,0,0,0.3);
  }

  .feature-card:hover::before { opacity: 1; }

  .feature-icon {
    width: 60px;
    height: 60px;
    background: linear-gradient(135deg, rgba(44,122,53,0.4), rgba(201,162,39,0.2));
    border-radius: 16px;
    display: flex;
    align-items: center;
    justify-content: center;
    font-size: 28px;
    margin: 0 auto 16px;
    border: 1px solid rgba(201,162,39,0.3);
  }

  .feature-title {
    font-family: 'Playfair Display', serif;
    font-size: 1rem;
    font-weight: 700;
    color: var(--gold-light);
    margin-bottom: 8px;
  }

  .feature-desc {
    font-size: 0.85rem;
    color: rgba(253,246,227,0.65);
    line-height: 1.6;
  }

  /* === PHONE MOCKUP SECTION === */
  .mockup-section {
    padding: 100px 20px;
    background: linear-gradient(180deg, #1a4a1e, #0d2b10);
    text-align: center;
  }

  .phone-frame {
    display: inline-block;
    background: linear-gradient(135deg, #1e1e1e, #2a2a2a);
    border-radius: 44px;
    border: 6px solid #333;
    box-shadow:
      0 0 0 2px #444,
      0 30px 80px rgba(0,0,0,0.6),
      0 0 60px rgba(201,162,39,0.15);
    overflow: hidden;
    width: min(300px, 80vw);
    position: relative;
  }

  .phone-screen {
    background: linear-gradient(160deg, #1a4a1e, #0d2b10);
    padding: 30px 20px;
    min-height: 520px;
    display: flex;
    flex-direction: column;
    align-items: center;
    justify-content: flex-start;
    gap: 16px;
  }

  .phone-app-title {
    font-family: 'Cinzel Decorative', serif;
    font-size: 1.5rem;
    color: var(--gold-light);
    text-align: center;
    margin-top: 10px;
  }

  .phone-search {
    width: 100%;
    background: rgba(255,255,255,0.12);
    border-radius: 30px;
    padding: 10px 18px;
    display: flex;
    align-items: center;
    gap: 8px;
    font-size: 13px;
    color: rgba(255,255,255,0.5);
    border: 1px solid rgba(255,255,255,0.15);
  }

  .wallet-row {
    display: flex;
    gap: 10px;
    width: 100%;
  }

  .wallet-card {
    flex: 1;
    background: rgba(201,162,39,0.15);
    border: 1px solid rgba(201,162,39,0.3);
    border-radius: 12px;
    padding: 12px;
    font-size: 12px;
    color: var(--gold-light);
    text-align: center;
  }

  .wallet-card .amount {
    font-size: 1rem;
    font-weight: 700;
    color: var(--cream);
    margin-top: 4px;
  }

  .mini-grid {
    display: grid;
    grid-template-columns: repeat(3, 1fr);
    gap: 8px;
    width: 100%;
  }

  .mini-btn {
    background: rgba(255,255,255,0.08);
    border-radius: 12px;
    padding: 12px 6px;
    text-align: center;
    font-size: 10px;
    color: var(--green-light);
    border: 1px solid rgba(255,255,255,0.1);
  }

  .mini-btn .icon { font-size: 18px; display: block; margin-bottom: 4px; }

  .phone-nav {
    display: flex;
    justify-content: space-around;
    width: 100%;
    padding: 12px 0 0;
    border-top: 1px solid rgba(255,255,255,0.1);
  }

  .nav-item {
    display: flex;
    flex-direction: column;
    align-items: center;
    font-size: 10px;
    color: rgba(255,255,255,0.5);
    gap: 4px;
  }

  .nav-item.active { color: var(--gold-light); }

  /* === STATS === */
  .stats {
    padding: 80px 20px;
    background: linear-gradient(135deg, #0d2b10, #1a4a1e);
  }

  .stats-grid {
    display: grid;
    grid-template-columns: repeat(auto-fit, minmax(180px, 1fr));
    gap: 30px;
    text-align: center;
  }

  .stat-item {
    padding: 30px 20px;
    border: 1px solid rgba(201,162,39,0.2);
    border-radius: 16px;
    background: rgba(255,255,255,0.03);
  }

  .stat-number {
    font-family: 'Cinzel Decorative', serif;
    font-size: 2.5rem;
    color: var(--gold-light);
    font-weight: 700;
    line-height: 1;
    margin-bottom: 8px;
  }

  .stat-label {
    font-size: 0.85rem;
    color: rgba(253,246,227,0.6);
    letter-spacing: 1px;
  }

  /* === CTA === */
  .cta {
    padding: 100px 20px;
    text-align: center;
    background:
      radial-gradient(ellipse at center, rgba(44,122,53,0.3) 0%, transparent 70%),
      linear-gradient(180deg, #0d2b10, #142e18);
    position: relative;
  }

  .cta-title {
    font-family: 'Cinzel Decorative', serif;
    font-size: clamp(1.8rem, 5vw, 3rem);
    color: var(--gold-light);
    margin-bottom: 20px;
  }

  .cta-desc {
    font-size: 1.05rem;
    color: rgba(253,246,227,0.7);
    max-width: 500px;
    margin: 0 auto 40px;
    line-height: 1.7;
  }

  .store-badges {
    display: flex;
    gap: 16px;
    justify-content: center;
    flex-wrap: wrap;
    margin-top: 20px;
  }

  .store-btn {
    display: flex;
    align-items: center;
    gap: 10px;
    background: rgba(255,255,255,0.08);
    border: 1px solid rgba(255,255,255,0.2);
    border-radius: 12px;
    padding: 12px 22px;
    color: var(--cream);
    text-decoration: none;
    transition: all 0.3s;
    font-size: 0.9rem;
  }

  .store-btn:hover {
    background: rgba(201,162,39,0.15);
    border-color: var(--gold);
    color: var(--gold-light);
    transform: translateY(-3px);
  }

  .store-btn .store-icon { font-size: 24px; }
  .store-btn .store-text small { display: block; font-size: 10px; opacity: 0.7; }
  .store-btn .store-text strong { font-size: 14px; }

  /* === FOOTER === */
  footer {
    background: #080f09;
    padding: 40px 20px;
    text-align: center;
    border-top: 1px solid rgba(201,162,39,0.2);
  }

  .footer-logo {
    font-family: 'Cinzel Decorative', serif;
    font-size: 1.4rem;
    color: var(--gold-light);
    margin-bottom: 12px;
  }

  .footer-tagline {
    font-size: 0.85rem;
    color: rgba(253,246,227,0.4);
    margin-bottom: 24px;
  }

  .footer-links {
    display: flex;
    gap: 24px;
    justify-content: center;
    flex-wrap: wrap;
    margin-bottom: 24px;
  }

  .footer-links a {
    color: rgba(253,246,227,0.5);
    text-decoration: none;
    font-size: 0.85rem;
    transition: color 0.2s;
  }

  .footer-links a:hover { color: var(--gold-light); }

  .footer-copy {
    font-size: 0.8rem;
    color: rgba(253,246,227,0.3);
  }

  /* === ANIMATIONS === */
  @keyframes fadeDown {
    from { opacity: 0; transform: translateY(-20px); }
    to { opacity: 1; transform: translateY(0); }
  }

  @keyframes fadeUp {
    from { opacity: 0; transform: translateY(20px); }
    to { opacity: 1; transform: translateY(0); }
  }

  /* Scroll fade-in */
  .fade-in {
    opacity: 0;
    transform: translateY(30px);
    transition: opacity 0.7s ease, transform 0.7s ease;
  }

  .fade-in.visible {
    opacity: 1;
    transform: none;
  }

  /* Decorative leaf pattern */
  .leaf-divider {
    text-align: center;
    font-size: 24px;
    margin: 20px 0;
    opacity: 0.5;
    letter-spacing: 10px;
  }

  /* Responsive */
  @media (max-width: 600px) {
    .btn-group { flex-direction: column; align-items: center; }
    .features-grid { grid-template-columns: repeat(2, 1fr); }
  }
</style>
</head>
<body>

<!-- HERO -->
<section class="hero">
  <div class="ornament-top"></div>

  <div class="hero-badge">✦ Berbasis Kearifan Lokal · SDGs Pariwisata ✦</div>

  <div class="hero-logo">🏛️</div>

  <h1 class="hero-title">Gaukang Tu Bajeng</h1>
  <p class="hero-subtitle">Pesona Budaya & Wisata Balla Lompoa Limbung</p>
  <div class="hero-divider"></div>
  <p class="hero-desc">
    Deskripsi singkat aplikasi Anda. Jelaskan apa yang dilakukan aplikasi ini, untuk siapa, dan nilai utama yang ditawarkan kepada pengguna.
  </p>

  <div class="btn-group">
    <a href="#" class="btn-primary">🔑 Login</a>
    <a href="#" class="btn-secondary">📝 Daftar</a>
    <a href="#" class="btn-ghost">Lihat sebagai Tamu →</a>
  </div>

  <div class="sdgs-row">
    <span class="sdg-badge">SDG 8 · Pekerjaan Layak</span>
    <span class="sdg-badge">SDG 11 · Komunitas</span>
    <span class="sdg-badge">SDG 17 · Kemitraan</span>
  </div>
</section>

<!-- ABOUT -->
<section class="about">
  <div class="container">
    <div class="section-header fade-in">
      <div class="section-tag">✦ Tentang Kami</div>
      <h2 class="section-title">Strategi Peningkatan<br>Kualitas Berbasis Lokal</h2>
      <p class="section-desc">Mengintegrasikan nilai-nilai kearifan lokal dengan sistem digital modern</p>
    </div>

    <div class="about-text-card fade-in">
      Aplikasi ini dirancang sebagai pusat aktivitas seni, budaya, dan pariwisata yang mengintegrasikan nilai-nilai kearifan lokal, ekspresi seni tradisional, serta sistem pengelolaan yang berkelanjutan melalui digitalisasi berbasis branding media sosial serta sistem informasi digital dan e-commerce.
      <br><br>
      <em>Ganti teks ini sesuai deskripsi aplikasi Anda yang sebenarnya.</em>
    </div>
  </div>
</section>

<!-- FEATURES -->
<section class="features">
  <div class="container">
    <div class="section-header fade-in">
      <div class="section-tag">✦ Fitur Unggulan</div>
      <h2 class="section-title">Semua yang Anda Butuhkan</h2>
    </div>

    <div class="features-grid">
      <div class="feature-card fade-in">
        <div class="feature-icon">🎭</div>
        <div class="feature-title">Kegiatan Seni Budaya</div>
        <p class="feature-desc">Eksplorasi kegiatan seni dan budaya lokal yang autentik dan beragam.</p>
      </div>
      <div class="feature-card fade-in">
        <div class="feature-icon">🏠</div>
        <div class="feature-title">Rumah Adat Digital</div>
        <p class="feature-desc">Informasi lengkap tentang arsitektur dan tradisi rumah adat setempat.</p>
      </div>
      <div class="feature-card fade-in">
        <div class="feature-icon">📊</div>
        <div class="feature-title">Sistem Informasi</div>
        <p class="feature-desc">Data dan informasi terstruktur untuk mendukung pengelolaan yang efektif.</p>
      </div>
      <div class="feature-card fade-in">
        <div class="feature-icon">🛒</div>
        <div class="feature-title">E-Commerce</div>
        <p class="feature-desc">Platform jual beli produk lokal secara digital dan mudah diakses.</p>
      </div>
      <div class="feature-card fade-in">
        <div class="feature-icon">📱</div>
        <div class="feature-title">Branding & Medsos</div>
        <p class="feature-desc">Strategi promosi digital terintegrasi untuk memperluas jangkauan.</p>
      </div>
      <div class="feature-card fade-in">
        <div class="feature-icon">🗺️</div>
        <div class="feature-title">Peta & Rute</div>
        <p class="feature-desc">Navigasi cerdas untuk menemukan destinasi dan rute terbaik.</p>
      </div>
    </div>
  </div>
</section>

<!-- PHONE MOCKUP -->
<section class="mockup-section">
  <div class="section-header fade-in" style="margin-bottom: 50px;">
    <div class="section-tag">✦ Tampilan Aplikasi</div>
    <h2 class="section-title">Dirancang untuk Kemudahan</h2>
  </div>

  <div class="phone-frame fade-in">
    <div class="phone-screen">
      <div class="phone-app-title">Gaukang Tu Bajeng</div>

      <div class="phone-search">
        🔍 <span>Cari di sini...</span>
      </div>

      <div class="wallet-row">
        <div class="wallet-card">
          <div>💰 Dompet</div>
          <div class="amount">Rp 350.000</div>
        </div>
        <div class="wallet-card">
          <div>⭐ Poin</div>
          <div class="amount">1.234</div>
        </div>
      </div>

      <div style="width:100%; font-size:12px; color: var(--gold); font-weight:700; letter-spacing:1px;">KATEGORI</div>

      <div class="mini-grid">
        <div class="mini-btn"><span class="icon">🔍</span>Semua</div>
        <div class="mini-btn"><span class="icon">🗺️</span>Peta</div>
        <div class="mini-btn"><span class="icon">⚙️</span>Lainnya</div>
        <div class="mini-btn"><span class="icon">🎁</span>Oleh-oleh</div>
        <div class="mini-btn"><span class="icon">📺</span>Medsos</div>
        <div class="mini-btn"><span class="icon">🎮</span>Budaya</div>
      </div>

      <div class="phone-nav">
        <div class="nav-item active"><span>🏠</span>Home</div>
        <div class="nav-item"><span>🔭</span>Explore</div>
        <div class="nav-item"><span>🛒</span>Keranjang</div>
        <div class="nav-item"><span>👤</span>Profil</div>
      </div>
    </div>
  </div>
</section>

<!-- STATS -->
<section class="stats">
  <div class="container">
    <div class="stats-grid fade-in">
      <div class="stat-item">
        <div class="stat-number">500+</div>
        <div class="stat-label">Pengguna Aktif</div>
      </div>
      <div class="stat-item">
        <div class="stat-number">50+</div>
        <div class="stat-label">Destinasi Terdaftar</div>
      </div>
      <div class="stat-item">
        <div class="stat-number">100+</div>
        <div class="stat-label">Produk Lokal</div>
      </div>
      <div class="stat-item">
        <div class="stat-number">4.8★</div>
        <div class="stat-label">Rating Pengguna</div>
      </div>
    </div>
  </div>
</section>

<!-- CTA -->
<section class="cta">
  <div class="fade-in">
    <div class="leaf-divider">🌿 🌺 🌿</div>
    <h2 class="cta-title">Mulai Perjalanan Anda</h2>
    <p class="cta-desc">Unduh aplikasi sekarang dan rasakan pengalaman wisata budaya yang tak terlupakan bersama komunitas lokal kami.</p>

    <div class="btn-group">
      <a href="#" class="btn-primary">Daftar Sekarang — Gratis</a>
      <a href="#" class="btn-secondary">Pelajari Lebih Lanjut</a>
    </div>

    <div class="store-badges">
      <a href="#" class="store-btn">
        <span class="store-icon">▶</span>
        <div class="store-text">
          <small>Tersedia di</small>
          <strong>Google Play</strong>
        </div>
      </a>
      <a href="#" class="store-btn">
        <span class="store-icon">🍎</span>
        <div class="store-text">
          <small>Unduh di</small>
          <strong>App Store</strong>
        </div>
      </a>
    </div>
  </div>
</section>

<!-- FOOTER -->
<footer>
  <div class="footer-logo">Gaukang Tu Bajeng</div>
  <div class="footer-tagline">Pesona Budaya & Wisata Balla Lompoa Limbung · Berbasis Kearifan Lokal</div>
  <div class="footer-links">
    <a href="#">Beranda</a>
    <a href="#">Tentang</a>
    <a href="#">Fitur</a>
    <a href="#">Kontak</a>
    <a href="#">Kebijakan Privasi</a>
  </div>
  <div class="footer-copy">© 2026 Gaukang Tu Bajeng. Hak Cipta Dilindungi.</div>
</footer>

<script>
  // Scroll-triggered fade-in
  const observer = new IntersectionObserver((entries) => {
    entries.forEach((entry, i) => {
      if (entry.isIntersecting) {
        setTimeout(() => entry.target.classList.add('visible'), i * 80);
      }
    });
  }, { threshold: 0.1 });

  document.querySelectorAll('.fade-in').forEach(el => observer.observe(el));
</script>
</body>
</html>
